# %% [markdown]
# <a href="https://colab.research.google.com/github/hafsssaet25/principle_python/blob/main/password_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import string
length = int(input("How long do you want the password? "))
characters = string.ascii_letters + string.digits + string.punctuation
password = "".join(random.choice(characters) for i in range (length))
print("your password is:", password)
# Out:
# How long do you want the password? 5
# your password is: }ga.C
