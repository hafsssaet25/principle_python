# %% [markdown]
# <a href="https://colab.research.google.com/github/hafsssaet25/principle_python/blob/main/Te_damos_la_bienvenida_a_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number = int(input("guess a number from 1 to 100: "))
while number!= 55
  if number > 55:
    print("too high")
  elif number < 55:
    print("too low ")
  number = int(input("guess a number from 1 to 100: "))
print("congratulations, you won !")
